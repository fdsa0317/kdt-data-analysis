# %% [markdown]
# ## 맷플로립(matplotlib)
#     - 파이썬의 자료(DataFrame, Series 등..)을 차트(chart)나 플롯(plot)으로 시각화(visualization)하는 모듈
#     - Matplotlib은 다음과 같은 정형화된 차트나 플롯 이외에도 저수준 api를 사용한 다양한 시각화 기능을 제공한다
#     - 라인 플롯(line plot)
#     - 스캐터 플롯(scatter plot)
#     - 컨투어 플롯(contour plot)
#     - 서피스 플롯(surface plot)
#     - 바 차트(bar chart)
#     - 히스토그램(histogram)
#     - 박스 플롯(box plot)
#     - 맷플로립은 라이브러리이다.
#
# [맷플로립 공식문서](https://matplotlib.org)

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ## Line plot(라인 플롯)
# - 가장 간단한 플롯
# - 선을 그리고 데이터가 시간, 순서 등에 따라 어떻게 변화되는지 보여주는 용도로 사용한다.

# %%
arr = np.array([10, 30, 14, 55])

plt.plot(arr)
plt.show()

# %%
arr = np.array([
    [10, 20, 30, 40],
    [20, 50, 33, 15],
    [17, 5, 2, 0],
])

plt.plot(arr)
plt.show()

# %%
# 윈도우 맑은 고딕 설정
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False  # 마이너스 기호 깨짐 방지

# %%
arr = np.array([
    [10, 20, 30, 40],
    [20, 50, 33, 15],
    [17, 5, 2, 0],
])

plt.figure(figsize=(10, 5))

for i, value in enumerate(arr):
    plt.subplot(111)
    plt.plot(arr[i])

plt.grid(True)
plt.title("라인 그래프")
plt.show()

# %%
x = np.arange(0, 5, 0.1)
y = x ** 3

plt.figure(figsize=(8, 4))
plt.plot(x, y)
plt.show()

# %%
test_df = pd.DataFrame(
    np.random.randn(10, 4).cumsum(axis=0),
    columns=["월", "화", "수", "목"],
    index=np.arange(0, 100, 10)
)

test_df
# Out:
#            월         화         수         목
# 0  -0.915976  2.743037 -0.373663 -0.741889
# 10 -1.885190  3.131266 -1.370710 -1.039147
# 20 -2.909734  2.210949 -2.438244 -1.425430
# 30 -2.133054  3.137209 -2.422001 -1.581452
# 40 -2.511053  2.731509 -3.199370 -2.059401
# 50 -1.125498  3.297703 -3.374509 -0.852316
# 60 -0.757560  4.857321 -4.034637 -1.182670
# 70 -1.166959  4.203694 -2.911261 -1.478144
# 80 -2.820773  4.299918 -3.950434 -1.409639
# 90 -3.986770  5.037352 -3.561522 -1.432100

# %%
plt.figure(figsize=(10, 5))
plt.plot(test_df)
# y축의 제목
plt.ylabel("y축")
# x축의 제목
plt.xlabel("X축")
# 범례
plt.legend(test_df.columns)
plt.show()

# %% [markdown]
# ## bar plot

# %%
np.random.seed(2002)
y = np.random.randint(100, size=10)
y

chr(97)

x = [chr(i) for i in range(97, 107)]
x
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

# %%
# plt.bar(x=x, height=y)
plt.bar(x, y)
plt.show()

# %%
s1 = pd.Series(data=y, index=x)
s1.plot(kind="bar")
# Out:
# <Axes: >

# %% [markdown]
# ## 히스토그램(histogram)
# - 도수분포표를 그리는 플롯
# - 가로축(계급), 세로축(도수)로 나타내는 그래프이다.

# %%
# 표준편차
plt.hist(np.random.normal(0, 1, size=1000))
plt.show()

# %% [markdown]
# ## 산포그래프(Scatter)
# - 산점도 서로 다른 두 개의 독립 변수에 대해 두 변수가 얼마나 상관관계를 가지는지 살펴보기 위해 그리는 그래프이다.

# %%
# normal(평균, 표준편차, 개수)
x1 = np.random.normal(0, 1, size=1000)
x2 = np.random.normal(5, 1, size=1000)
y = np.random.normal(0, 2, size=1000)

# %%
plt.figure(figsize=(8, 4))
plt.scatter(x1, x2)
plt.show()

# %%
plt.figure(figsize=(8, 4))
plt.scatter(x1, y)
plt.scatter(x2, y)
plt.show()

# %% [markdown]
# ## subplot

# %%
fig = plt.figure()

fig.show()
# Out:
# C:\Users\fdsa0\AppData\Local\Temp\ipykernel_14468\853111686.py:3: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
# 가로2개, 세로2개로 나누고 첫 번째 플롯
ax1 = fig.add_subplot(2, 2, 1)
# 가로2개, 세로2개로 나누고 두 번째 플롯
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)
ax4 = fig.add_subplot(2, 2, 4)

# %%
fig

# %%
ax1.hist(x1)
ax2.plot(x2)
ax3.scatter(x1, y)

y1 = np.random.randint(100, size=10)
y1
ax4.bar(x, y1)

# ax1.set_xticks([])
# ax1.set_xticks([])

fig

# %%
arr = np.array([10, 30, 14, 55])

plt.plot(arr, color="yellow", marker="*", linestyle="-.")
plt.show()
